# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shapely.geometry
import seaborn as sns
import plotly.express as px
import re
from matplotlib.colors import TwoSlopeNorm
import missingno as msno
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl
import math

# %%
import plotly.io as pio
pio.renderers.default = 'notebook_connected'
pd.set_option('display.max_columns', None)

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams['figure.dpi'] = 200

# %%
# Projected Coordinate System: how you project onto a 2D plane
epsg_2d = 26717 
# Toronto Police Service Open Data includes geographic location information provided in
# the projected coordinate system NAD 1927 UTM 17N
# https://epsg.io/26717

# Geographic Coordinate System: how coordinates are represented in a 3D space
# World Geodetic System 1984 (WGS84)
# https://epsg.io/4326
epsg_3d = 4326

# %% [markdown]
# # TTC station locations

# %%
stations_point = gpd.read_file('./clean_data/stations_point.geojson')
stations_area = gpd.read_file('./clean_data/stations_area.geojson')

# %%
# radius in km
radius = (stations_area.to_crs(epsg_2d)['geometry'].iloc[0].area / np.pi)**0.5 / 10**3

# %%
ax = stations_area.plot(column = 'line', 
                        edgecolor = 'black', 
                        alpha = 0.5,
                        cmap = 'tab20',
                        legend = True,
                        legend_kwds = {'loc': 'upper right', 
                                       'ncol': 2,
                                       'edgecolor': 'lightgrey'})
stations_point.plot(ax=ax, 
                    color = 'blue', 
                    markersize = 3)
plt.title(f'TTC subway stations with surrounding radius of {radius:0.2f}km')
# Out:
# Text(0.5, 1.0, 'TTC subway stations with surrounding radius of 0.40km')

# %% [markdown]
# # Neighbourhood population and distance from UofT

# %%
neighbourhoods = gpd.read_file('./clean_data/neighbourhoods.geojson')
neighbourhoods.head()
# Out:
#              Neighbourhood Hood_ID district  distance_km  Population_2014  \
# 0           Yonge-St.Clair      97      C02     2.791462            12597
# 1  York University Heights      27      W05    13.676191            28719
# 2         Lansing-Westgate      38      C07    10.427749            16086
# 3       Yorkdale-Glen Park      31      W04     7.592207            15196
# 4      Stonegate-Queensway      16      W07     9.017845            25636
#
#    Population_2015  Population_2016  Population_2017  Population_2018  \
# 0            12746            12950            13214            13508
# 1            28612            28597            28981            29422
# 2            16376            16722            17053            17429
# 3            15187            15228            15797            18722
# 4            25679            25782            26165            26601
#
#    Population_2019  Population_2020  PIC_Count2014  PIC_Count2015  \
# 0            13789            14082           61.0           83.0
# 1            29847            30277          256.0          327.0
# 2            17784            18146           94.0           94.0
# 3            16970            17560          146.0          131.0
# 4            27006            27409          145.0          129.0
#
#    PIC_Count2016  PIC_Count2017  PIC_Count2018  PIC_Count2019  PIC_Count2020  \
# 0           73.0           62.0           81.0           86.0           93.0
# 1          322.0          322.0          379.0          395.0          363.0
# 2          108.0          109.0          131.0          131.0          117.0
# 3          154.0          173.0          192.0          216.0          227.0
# 4          127.0          122.0          150.0          131.0          146.0
#
#    PIC_Density2014  PIC_Density2015  PIC_Density2016  PIC_Density2017  \
# 0        52.526545        71.470544        62.859635        53.387635
# 1        19.325509        24.685319        24.307867        24.307867
# 2        17.582755        17.582755        20.201463        20.388514
# 3        24.178636        21.694530        25.503493        28.650028
# 4        18.247086        16.233614        15.981930        15.352721
#
#    PIC_Density2018  PIC_Density2019  PIC_Density2020  PIC_Rate2014  \
# 0        69.748363        74.053817        80.081453    484.242280
# 1        28.610813        29.818657        27.402968    891.395940
# 2        24.503627        24.503627        21.884919    584.359070
# 3        31.796562        35.771133        37.592811    960.779152
# 4        18.876296        16.485298        18.372928    565.610860
#
#    PIC_Rate2015  PIC_Rate2016  PIC_Rate2017  PIC_Rate2018  PIC_Rate2019  \
# 0    651.184685    563.706564    469.199334    599.644655    623.685546
# 1   1142.877114   1125.992237   1111.072772   1288.151723   1323.416089
# 2    574.010747    645.855759    639.183721    751.620862    736.617184
# 3    862.579838   1011.294983   1095.144648   1025.531460   1272.834414
# 4    502.356011    492.591731    466.271737    563.888576    485.077390
#
#    PIC_Rate2020  MentalHealth_Count2014  MentalHealth_Count2015  \
# 0    660.417554                    18.0                    30.0
# 1   1198.929881                   121.0                   128.0
# 2    644.770197                    33.0                    24.0
# 3   1292.710706                    33.0                    36.0
# 4    532.671750                    54.0                    59.0
#
#    MentalHealth_Count2016  MentalHealth_Count2017  MentalHealth_Count2018  \
# 0                    24.0                    27.0                    27.0
# 1                   160.0                   188.0                   211.0
# 2                    36.0                    33.0                    35.0
# 3                    50.0                    47.0                    55.0
# 4                    45.0                    41.0                    47.0
#
#    MentalHealth_Count2019  MentalHealth_Count2020  MentalHealth_Density2014  \
# 0                    33.0                    42.0                 15.499636
# 1                   191.0                   191.0                  9.134323
# 2                    47.0                    41.0                  6.172669
# 3                    76.0                    81.0                  5.465034
# 4                    41.0                    47.0                  6.795466
#
#    MentalHealth_Density2015  MentalHealth_Density2016  \
# 0                 25.832727                 20.666181
# 1                  9.662755                 12.078443
# 2                  4.489214                  6.733821
# 3                  5.961855                  8.280355
# 4                  7.424676                  5.662889
#
#    MentalHealth_Density2017  MentalHealth_Density2018  \
# 0                 23.249454                 23.249454
# 1                 14.192171                 15.928447
# 2                  6.172669                  6.546771
# 3                  7.783533                  9.108390
# 4                  5.159521                  5.914573
#
#    MentalHealth_Density2019  MentalHealth_Density2020  MentalHealth_Rate2014  \
# 0                 28.416000                 36.165818             142.891165
# 1                 14.418642                 14.418642             421.323862
# 2                  8.791378                  7.669074             205.147333
# 3                 12.586139                 13.414175             217.162411
# 4                  5.159521                  5.914573             210.641286
#
#    MentalHealth_Rate2015  MentalHealth_Rate2016  MentalHealth_Rate2017  \
# 0             235.367959             185.328185             204.328742
# 1             447.364742             559.499248             648.700873
# 2             146.555936             215.285253             193.514338
# 3             237.044841             328.342527             297.524846
# 4             229.759726             174.540377             156.697879
#
#    MentalHealth_Rate2018  MentalHealth_Rate2019  MentalHealth_Rate2020  \
# 0             199.881552             239.321198             298.253089
# 1             717.150432             639.930311             630.841893
# 2             200.814734             264.282501             225.945112
# 3             293.772033             447.849146             461.275626
# 4             176.685087             151.818114             171.476522
#
#                                             geometry
# 0  POLYGON ((-79.39115 43.68108, -79.39137 43.680...
# 1  POLYGON ((-79.50525 43.75987, -79.50484 43.759...
# 2  POLYGON ((-79.43994 43.76156, -79.44000 43.761...
# 3  POLYGON ((-79.43965 43.70561, -79.44007 43.705...
# 4  POLYGON ((-79.49258 43.64744, -79.49273 43.647...

# %%
ax = neighbourhoods.plot(color = 'lightgreen', edgecolor = 'black', alpha = 0.5)
# annotate neighbourhood names
for geometry, label in zip(neighbourhoods.geometry, neighbourhoods.Hood_ID):
    ax.annotate(label, xy=(geometry.centroid.x, geometry.centroid.y), ha='center')

# %%
fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=-1)
im2 = neighbourhoods.plot(column = 'distance_km', 
                         cmap = 'bwr',
                         legend = True,
                         ax = ax,
                         cax = cax)
ax.set_title('Distance in km from University of Toronto St. George campus')
# Out:
# Text(0.5, 1.0, 'Distance in km from University of Toronto St. George campus')

# %%
counts = sorted(list(set([re.search('[a-zA-Z]+_Count', x).group(0) for x in neighbourhoods.columns.values if re.search('[a-zA-Z]+_Count', x) is not None])))
counts
# Out:
# ['MentalHealth_Count', 'PIC_Count']

# %%
rates = sorted(list(set([re.search('[a-zA-Z]+_Rate', x).group(0) for x in neighbourhoods.columns.values if re.search('[a-zA-Z]+_Rate', x) is not None])))
rates
# Out:
# ['MentalHealth_Rate', 'PIC_Rate']

# %%
desities = sorted(list(set([re.search('[a-zA-Z]+_Density', x).group(0) for x in neighbourhoods.columns.values if re.search('[a-zA-Z]+_Density', x) is not None])))
desities
# Out:
# ['MentalHealth_Density', 'PIC_Density']

# %%
years = sorted(list(set([re.search('[0-9]+', x).group(0) for x in neighbourhoods.columns.values if re.search('[0-9]+', x) is not None])))
years
# Out:
# ['2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
population = sorted(list(set([re.search('Population_\d{4}', x).group(0) for x in neighbourhoods.columns.values if re.search('Population_\d{4}', x) is not None])))
population
# Out:
# ['Population_2014',
#  'Population_2015',
#  'Population_2016',
#  'Population_2017',
#  'Population_2018',
#  'Population_2019',
#  'Population_2020']

# %%
def plot_one(var, title, row, col):
    fig, axes = plt.subplots(row, col)

    # fix the range for the colorbar so we can compare across years
    vmin, vmax = neighbourhoods[[var + str(year) for year in years]].min().min(), neighbourhoods[[var + str(year) for year in years]].max().max()
    norm = TwoSlopeNorm(vmin=vmin, vcenter= np.mean([vmin, vmax]), vmax=vmax)
    
    for ax in axes.flatten():
        ax.xaxis.set_visible(False)
        ax.set_yticks([])
    
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
    cax = plt.axes([0.85, 0.1, 0.05, 0.8])
    for year, ax in zip(years, axes.flatten()):
        neighbourhoods.plot(column = var + str(year), 
                            cmap = 'bwr',
                            norm = norm,
                            ax = ax, 
                            # cax = cax,
                            # legend = True,
                            )
        ax.set_title(year)

    fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='bwr'), cax=cax, orientation='vertical')
    
    fig.suptitle(title, size='xx-large')

# %%
plot_one('Population_', 'Population in City of Toronto', 3, 3)

# %%
plot_one('MentalHealth_Rate', 'Mental Health Apprehensions per 100k population in City of Toronto', 3, 3)

# %%
plot_one('PIC_Rate', 'Person-In-Crisis Calls for Services per 100k population in City of Toronto', 3, 3)
