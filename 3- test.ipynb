# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get('https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto#cite_note-JS_TREB_MLS_table-7')
soup = BeautifulSoup(r.text)
table = soup.find('table', {'class' : 'wikitable sortable'})
df = pd.read_html(str(table))[0]

# %%
for x in df.set_index('District Number').to_dict()['Neighbourhoods Included']:
    print(x)
# Out:
# C01
# C02
# C03
# C04
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# E01
# E02
# E03
# E04
# E05
# E06
# E07
# E08
# E09
# E10
# E11
# W01
# W02
# W03
# W04
# W05
# W06
# W07
# W08
# W09
# W10

# %%
my_dict = {}

# %%
for key, value in df.set_index('District Number').to_dict()['Neighbourhoods Included'].items():
    for x in value.split(','):
        my_dict[x.strip()] = key

# %%
my_dict
# Out:
# {'Downtown': 'C01',
#  'Harbourfront': 'C01',
#  'Little Italy': 'C01',
#  'Little Portugal': 'C01',
#  'Dufferin Grove': 'C01',
#  'Palmerston': 'C01',
#  'University': 'C01',
#  'Bay Street Corridor': 'C01',
#  'Kensington Market': 'C01',
#  'Chinatown': 'C01',
#  'Trinity Bellwoods': 'C01',
#  'South Niagara': 'C01',
#  'Island airport': 'C01',
#  'The Islands': 'C01',
#  'waterfront communities C1': 'C01',
#  "Queen's Park": 'C01',
#  'Ontario Provincial Government': 'C01',
#  'Victoria Hotel': 'C01',
#  'Central Bay Street': 'C01',
#  'First Canadian Place': 'C01',
#  'Design Exchange': 'C01',
#  'Adelaide': 'C01',
#  'University of Toronto': 'C01',
#  'Union Station': 'C01',
#  'The Annex': 'C02',
#  'Yorkville': 'C02',
#  'South Hill': 'C02',
#  'Summerhill': 'C02',
#  'Wychwood Park': 'C02',
#  'Deer Park': 'C02',
#  'Casa Loma': 'C02',
#  'Forest Hill South': 'C03',
#  'Oakwood–Vaughan': 'C03',
#  'Humewood–Cedarvale': 'C03',
#  'Corso Italia': 'W03',
#  'Forest Hill Road Park': 'C03',
#  'Bedford Park': 'C04',
#  'Lawrence Manor': 'C04',
#  'North Toronto': 'C04',
#  'Forest Hill North': 'C04',
#  'Lawrence Park': 'C04',
#  'Lawrence Heights': 'C04',
#  'Roselawn': 'C04',
#  'North York': 'C06',
#  'Clanton Park': 'C06',
#  'Bathurst Manor': 'C06',
#  'Willowdale West': 'C07',
#  'Newtonbrook West': 'C07',
#  'Westminster–Branson': 'C07',
#  'Lansing-Westgate': 'C07',
#  'Cabbagetown': 'C08',
#  'St. Lawrence Market': 'C08',
#  'Toronto waterfront': 'C08',
#  'Moss Park': 'C08',
#  'Church and Wellesley': 'C08',
#  'Garden District': 'C08',
#  'Regent Park': 'C08',
#  'St. James Town': 'C08',
#  'Ryerson': 'C08',
#  'Berczy Park': 'C08',
#  'Moore Park': 'C09',
#  'Rosedale': 'C09',
#  'Davisville Village': 'C10',
#  'Midtown Toronto': 'C10',
#  'Mount Pleasant': 'C10',
#  'Davisville North': 'C10',
#  'Davisville': 'C10',
#  'Leaside': 'C11',
#  'Thorncliffe Park': 'C11',
#  'Flemingdon Park': 'C11',
#  'York Mills': 'C12',
#  'St.Andrew - Windfields': 'C12',
#  'Bridle Path': 'C12',
#  'Sunnybrook': 'C12',
#  'York Mills West': 'C12',
#  'Don Mills': 'C13',
#  'Parkwoods–Donalda': 'C13',
#  'Victoria Village': 'C13',
#  'Banbury': 'C13',
#  'Parkwoods': 'C13',
#  'Newtonbrook East': 'C14',
#  'Willowdale East': 'C14',
#  'Newtonbrook': 'C14',
#  'Hillcrest Village': 'C15',
#  'Bayview Woods-Steeles': 'C15',
#  'Bayview Village': 'C15',
#  'Don Valley Village': 'C15',
#  'Henry Farm': 'C15',
#  'Pleasant View': 'C15',
#  'Riverdale': 'E01',
#  'Danforth (Greektown)': 'E03',
#  'Leslieville': 'E01',
#  'Blake-Jones': 'E01',
#  'Greenwood': 'E01',
#  'Coxwell': 'E01',
#  'Studio District': 'E01',
#  'The Beaches': 'E02',
#  'Woodbine Corridor': 'E02',
#  'East End - Danforth': 'E02',
#  'The Beaches West': 'E02',
#  'South Central Letter Processing Plant Toronto': 'E02',
#  'East York': 'E03',
#  'Playter Estates': 'E03',
#  'Broadview North (Old East York)': 'E03',
#  "O'Connor–Parkview": 'E03',
#  'Crescent Town': 'E03',
#  'Woodbine Heights': 'E03',
#  'Woodbine Gardens': 'E03',
#  'Parkview Hill': 'E03',
#  'The Golden Mile': 'E04',
#  'Dorset Park': 'E04',
#  'Wexford': 'E04',
#  'Maryvale': 'E04',
#  'Scarborough Junction (Kennedy Park)': 'E04',
#  'Ionview': 'E04',
#  'Clairlea': 'E04',
#  'Birchmount': 'E04',
#  'Steeles': 'E05',
#  "L'Amoreaux West": 'E05',
#  "Tam O'Shanter – Sullivan": 'E05',
#  'Clarks Corners': 'E05',
#  "L'Amoreaux": 'E05',
#  'Birch Cliff': 'E06',
#  'Oakridge': 'E06',
#  'Hunt Club': 'E06',
#  'Cliffside': 'E06',
#  'Agincourt': 'E07',
#  'Malvern West': 'E07',
#  'Milliken': 'E07',
#  'Scarborough Village': 'E08',
#  'Cliffcrest': 'E08',
#  'Guildwood': 'E08',
#  'Eglinton East (Knob Hill)': 'E08',
#  'Scarborough City Centre': 'E09',
#  'Woburn': 'E09',
#  'Morningside': 'E09',
#  'Bendale (Cedarbrae)': 'E09',
#  'Cedarbrae': 'E09',
#  'Rouge (South)': 'E10',
#  'Port Union (Centennial Scarborough)': 'E10',
#  'West Hill': 'E10',
#  'Highland Creek': 'E10',
#  'Port Union': 'E10',
#  'Rouge (West)': 'E11',
#  'Malvern': 'E11',
#  'Rouge': 'E11',
#  'Upper Rouge': 'E11',
#  'High Park': 'W01',
#  'South Parkdale': 'W01',
#  'Swansea': 'W01',
#  'Roncesvalles Village': 'W01',
#  'Roncesvalles': 'W01',
#  'Parkdale Village': 'W01',
#  'Bloor West Village': 'W02',
#  'Baby Point': 'W02',
#  'The Junction (Junction Area)': 'W02',
#  'High Park North': 'W02',
#  'Runnymede': 'W02',
#  'Dovercourt Village': 'W02',
#  'Christie': 'W02',
#  'Keelesdale': 'W03',
#  'Eglinton West': 'W03',
#  'Rockcliffe–Smythe': 'W03',
#  'Weston-Pellam Park': 'W03',
#  'Davenport': 'W03',
#  'Caledonia-Fairbanks': 'W03',
#  'York': 'W04',
#  'Glen Park': 'W04',
#  'Amesbury (Brookhaven)': 'W04',
#  'Pelmo Park – Humberlea': 'W04',
#  'Weston': 'W04',
#  'Fairbank (Briar Hill-Belgravia)': 'W04',
#  'Maple Leaf': 'W04',
#  'Mount Dennis': 'W04',
#  'Pelmo Park – Humberlea W4': 'W04',
#  'Beechborough': 'W04',
#  'Greenbrook': 'W04',
#  'Yorkdale': 'W04',
#  'Rustic': 'W04',
#  'Glencairn': 'W04',
#  'Upwood Park': 'W04',
#  'Downsview': 'W05',
#  'Humber Summit': 'W05',
#  'Humbermede (Emery)': 'W05',
#  'Jane and Finch (Black Creek or Glenfield-Jane Heights)': 'W05',
#  'York University Heights': 'W05',
#  'York University': 'W05',
#  'Pelmo Park – Humberlea W5': 'W05',
#  'Downsview-Roding-CFB': 'W05',
#  'Emery': 'W05',
#  'New Toronto': 'W06',
#  'Long Branch': 'W06',
#  'Mimico': 'W06',
#  'Alderwood': 'W06',
#  'Humber Bay Shores': 'W06',
#  'Sunnylea (The Queensway – Humber Bay)': 'W07',
#  'Sunnylea': 'W07',
#  'Stonegate - Queenway': 'W07',
#  'Thompson Orchard': 'W07',
#  'The Kingsway': 'W08',
#  'Central Etobicoke': 'W08',
#  'Eringate – Centennial – West Deane': 'W08',
#  'Princess-Rosethorn': 'W08',
#  'Edenbridge-Humber Valley': 'W08',
#  'Islington–City Centre West': 'W08',
#  'Markland Wood': 'W08',
#  'Royal York South West': 'W08',
#  'Princess Gardens': 'W08',
#  'Humber Valley Village': 'W08',
#  'Kingsview Village-The Westway': 'W09',
#  'Richview (Willowridge)': 'W09',
#  'Humber Heights – Westmount': 'W09',
#  'Martin Grove Gardens': 'W09',
#  'Kingsview Village': 'W09',
#  'Westmount': 'W09',
#  'Rexdale': 'W10',
#  'Clairville': 'W10',
#  'Thistletown - Beaumond Heights': 'W10',
#  'Smithfield: Mount Olive-Silverstone-Jamestown': 'W10',
#  'The Elms (Elms-Old Rexdale)': 'W10',
#  'West Humber - Clairville': 'W10',
#  'Mount Olive': 'W10'}
